# %%
import pandas as pd

df = pd.read_csv(r"catami-classification\catami-caab-codes.csv", delimiter=",")

json_output = df.to_json(orient="records", indent=4)

with open(r"catami-classification\catami-caab.json", "w") as f:
    f.write(json_output)

print(json_output)
# Out:
# [
#     {
#         "SPECIES_CODE":35000000,
#         "CATAMI_DISPLAY_NAME":"Ascidians",
#         "CATAMI_PARENT_ID":80000000.0,
#         "CPC_CODES":" A "
#     },
#     {
#         "SPECIES_CODE":35000904,
#         "CATAMI_DISPLAY_NAME":"Ascidians: Stalked",
#         "CATAMI_PARENT_ID":35000000.0,
#         "CPC_CODES":" AS "
#     },
#     {
#         "SPECIES_CODE":35000906,
#         "CATAMI_DISPLAY_NAME":"Ascidians: Stalked: Colonial",
#         "CATAMI_PARENT_ID":35000904.0,
#         "CPC_CODES":" ASC "
#     },
#     {
#         "SPECIES_CODE":35000905,
#         "CATAMI_DISPLAY_NAME":"Ascidians: Stalked: Solitary",
#         "CATAMI_PARENT_ID":35000904.0,
#         "CPC_CODES":" ASS "
#     },
#     {
#         "SPECIES_CODE":35000901,
#         "CATAMI_DISPLAY_NAME":"Ascidians: Unstalked",
#         "CATAMI_PARENT_ID":35000000.0,
#         "CPC_CODES":" AU "
#     },
#     {
#         "SPECIES_CODE":35000903,
# ...
